# %% [markdown]
# # Tensor Flow Playground

# %% [markdown]
# ![image.png](attachment:8008cd61-d3d2-424e-95a0-9a8e5e5e8c01.png)

# %% [markdown]
# ![image.png](attachment:861c616c-8bd5-4af9-b0e5-82fdddc66a58.png)

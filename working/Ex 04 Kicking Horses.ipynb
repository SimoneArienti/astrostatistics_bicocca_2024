# %% [markdown]
# # Kicking Horses
#
# A famous early  application of low-number statistics was an analysis of Prussian cavalryman horse-kick deaths by [Bortkiewicz](https://www.wikiwand.com/en/Ladislaus_Bortkiewicz) in 1898.
#
# He studied the distribution of 122 men kicked to death by horses among 10 Prussian army corps within 20 years (so a total number of corpes of 200). He recorded the number of corps with a given number of deaths:
#
# | Number of deaths | Number of groups |
# | --- | --- |
# | 0 | 109 |
# | 1 | 65 |
# | 2 | 22 |
# | 3 | 3 |
# | 4 | 1 |
#
# - Plot the resulting probability distribution. Careful with the normalization
# - How does it look like? Again try to fit it by hand.
#
# (Hint: think about sample mean and sample variance)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# %% [markdown]
# First I have to build up the distribution

# %%
deaths = np.array([0, 1, 2, 3, 4])
groups = np.array([109, 65, 22, 3, 1])

plt.bar(deaths, groups, align='center', alpha=0.4, label='Data')
plt.xlabel('Deaths')
plt.ylabel('Frequency')
plt.title('N° of Deaths vs N° of Groups')
plt.legend()

# %% [markdown]
# Now I plot the results but I first need to normalize them in order to get the probabilities!

# %%
total_groups = np.sum(groups) 
probabilities = groups / total_groups

plt.bar(deaths, probabilities, align='center', alpha=0.4, label='Data')
plt.xlabel('Deaths')
plt.ylabel('Probabilities')
plt.title('N° of Deaths vs Probabilities')
plt.legend()

# %% [markdown]
# Now I suppose that my data are distributed in according to a Poisson distribution.

# %%
mu = np.sum(deaths*groups) / np.sum(groups)
poisson_distribution = poisson(mu)

# %%
x = np.arange(0, 5)
plt.bar(deaths, probabilities, align='center', alpha=0.4, label='Data')
plt.plot(x, poisson_distribution.pmf(x), 'ro-', label='Poisson Fit')
plt.xlabel('Deaths')
plt.ylabel('Probability')
plt.title('Histogram with Poisson Fit')
plt.legend()
plt.xticks(deaths)
plt.show()

# %% [markdown]
# The distribution can be considered as a **Poisson distribution**.
